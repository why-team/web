# %%
import pickle

# %%
with open('bm25model.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model.get_scores

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/wzl/nltk_data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import nltk
# ----> 2 nltk.download('stopwords')
#
# File ~/miniconda3/envs/backend2/lib/python3.9/site-packages/nltk/downloader.py:777, in Downloader.download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     768 def show(s, prefix2=""):
#     769     print_to(
#     770         textwrap.fill(
#     771             s,
#    (...)
#     774         )
#     775     )
# --> 777 for msg in self.incr_download(info_or_id, download_dir, force):
#     778     # Error messages
#     779     if isinstance(msg, ErrorMessage):
#     780         show(msg.message)
#
# ...
